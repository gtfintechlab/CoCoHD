# %% [markdown]
# # Hearing Details Cleaning
# ### Standardize hearing detail JSONs into one file

# %%
import pandas as pd
import json

def standardize_json(json_file_path):
  with open(json_file_path, 'r') as json_file:
    data = json.load(json_file)

  df = pd.DataFrame(data)

  selected_columns = ['govinfo_id', 'Title', 'Congress', 'Congress Chamber', 'Held Date', 'Committee and Subcommittee', 'Members', 'Bill Numbers', 'Witnesses']
  new_column_names = {'Title': 'title', 'Congress': 'congress_session', 'Congress Chamber': 'chamber', 'Held Date': 'held_date', 'Committee and Subcommittee': 'committee', 'Members': 'members', 'Bill Numbers': 'bill_numbers', 'Witnesses': 'witnesses'}
  df_standardized = df[selected_columns].rename(columns=new_column_names)
  df_standardized['congress_session'] = df_standardized['congress_session'].str.replace(r'th$', '', regex=True)

  return df_standardized

# %%
def map_committee_name(df):
    print('map_committee_name: Mapping different committee names of the same committee to the same name')
    with open('../datasets/committee_name_mapping.json', 'r') as f:
        committee_name_mapping = json.load(f)

    def get_mapped_committee_name(chamber, committee):
        if chamber not in committee_name_mapping: return committee
        if committee not in committee_name_mapping[chamber]: return committee
        return committee_name_mapping[chamber][committee]

    df['committee_mapped'] = df.apply(lambda row: get_mapped_committee_name(row['chamber'], row['committee']), axis=1)
    column_order = ['govinfo_id', 'title', 'congress_session', 'chamber', 'committee', 'committee_mapped', 'held_date', 'members', 'bill_numbers', 'witnesses']
    df = df[column_order]
    return df

# %%
import os

all_dataframes = []

for json_file_name in os.listdir('../datasets/hearing_details/'):
    try:
        all_dataframes.append(standardize_json(f"../datasets/hearing_details/{json_file_name}"))
    except Exception as e:
        print(f"Getting exception at {json_file_name}")

df_combined = pd.concat(all_dataframes, ignore_index=True)
print('Combined all JSONs in to one dataframe, standardized each JSON')
df_mapped = map_committee_name(df_combined)
df_mapped
# Out:
# Combined all JSONs in to one dataframe, standardized each JSON
# map_committee_name: Mapping different committee names of the same committee to the same name
#               govinfo_id                                              title  \
# 0      CHRG-109shrg26254  S. Hrg. 109-291 - Repeal Act of May 26, 1936, ...
# 1      CHRG-109shrg22720  S. Hrg. 109-337 - Review the Reauthorization o...
# 2      CHRG-109shrg20612  S. Hrg. 109-089 - To Consider the Reauthorizat...
# 3      CHRG-109shrg97781  S. Hrg. 109-012 - Nomination of Hon. Michael J...
# 4      CHRG-109shrg20839  S. Hrg. 109-274 - Nomination of Hon. Thomas C....
# ...                  ...                                                ...
# 32690  CHRG-105shrg50137  S. Hrg. 105-628 - International Banking & Fina...
# 32691  CHRG-105shrg51128  S. Hrg. 105-770 - The Year 2000 Technology Pro...
# 32692  CHRG-105shrg51127  S. Hrg. 105-777 - Transportation After Y2k: Ca...
# 32693  CHRG-105shrg44791  S. Hrg. 105-376 - U.S. and Mexican Counterdrug...
# 32694  CHRG-105shrg51088  S. Hrg. 105-844 - U.S. Anti-Drug Interdiction ...
#
#       congress_session chamber  \
# 0                  109  Senate
# 1                  109  Senate
# 2                  109  Senate
# 3                  109  Senate
# 4                  109  Senate
# ...                ...     ...
# 32690              105  Senate
# 32691              105  Senate
# 32692              105  Senate
# 32693              105  Senate
# 32694              105  Senate
#
#                                                committee  \
# 0              Committee on Energy and Natural Resources
# 1      Committee on Agriculture, Nutrition, and Forestry
# 2      Committee on Agriculture, Nutrition, and Forestry
# 3      Committee on Agriculture, Nutrition, and Forestry
# 4      Committee on Agriculture, Nutrition, and Forestry
# ...                                                  ...
# 32690  Special Committee on Year 2000 Technology Problem
# 32691  Special Committee on Year 2000 Technology Problem
# 32692  Special Committee on Year 2000 Technology Problem
# 32693  United States Senate Caucus on International N...
# 32694  United States Senate Caucus on International N...
#
#                                         committee_mapped  \
# 0              Committee on Energy and Natural Resources
# 1      Committee on Agriculture, Nutrition, and Forestry
# 2      Committee on Agriculture, Nutrition, and Forestry
# 3      Committee on Agriculture, Nutrition, and Forestry
# 4      Committee on Agriculture, Nutrition, and Forestry
# ...                                                  ...
# 32690  Special Committee on Year 2000 Technology Problem
# 32691  Special Committee on Year 2000 Technology Problem
# 32692  Special Committee on Year 2000 Technology Problem
# 32693  United States Senate Caucus on International N...
# 32694  United States Senate Caucus on International N...
#
#                            held_date  \
# 0                   October 25, 2005
# 1                       May 25, 2005
# 2      March 8, 2005\nMarch 10, 2005
# 3                    January 6, 2005
# 4                     April 27, 2005
# ...                              ...
# 32690                   July 6, 1998
# 32691             September 17, 1998
# 32692             September 10, 1998
# 32693               October 29, 1997
# 32694             September 16, 1998
#
#                                                  members  \
# 0      LISA MURKOWSKI of Alaska (AK); DIANNE FEINSTEI...
# 1      Max Baucus (MT); Saxby Chambliss (GA); Thad Co...
# 2      Max Baucus (MT); Saxby Chambliss (GA); Thad Co...
# 3      Max Baucus (MT); Saxby Chambliss (GA); Thad Co...
# 4      Max Baucus (MT); Saxby Chambliss (GA); Thad Co...
# ...                                                  ...
# 32690  Robert F. Bennett (UT); Jeff Bingaman (NM); Ro...
# 32691  Robert F. Bennett (UT); Jeff Bingaman (NM); Ro...
# 32692  Robert F. Bennett (UT); Jeff Bingaman (NM); Ro...
# 32693  John Ashcroft (MO); Joseph R. Biden Jr. (DE); ...
# 32694  John Ashcroft (MO); Joseph R. Biden Jr. (DE); ...
#
#                                       bill_numbers  \
# 0      H.R. 59\nS. 1829\nS. 1830\nS. 1831\nS. 3378
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 32690                  S. 22\nS. Res. 208\nS. 1518
# 32691           S. Res. 208\nS. Res. 2000\nS. 2392
# 32692                         S. Res. 208\nS. 2392
# 32693                                          NaN
# 32694                           S. 2341\nH.R. 3809
#
#                                                witnesses
# 0                                                    NaN
# 1      Dahl, Tom, President, American Association of ...
# 2      Brown-Hruska, Sharon, Chairman, Commodity Futu...
# 3      Hagel, Hon. Chuck, a U.S. Senator from Nebrask...
# 4      Dorr, Hon. Thomas C., of Iowa, to be Under Sec...
# ...                                                  ...
# 32690                                                NaN
# 32691                                                NaN
# 32692                                                NaN
# 32693                                                NaN
# 32694                                                NaN
#
# [32695 rows x 10 columns]

# %% [markdown]
# ### Dataset Validation

# %%
df_mapped.isna().sum()
# Out:
# govinfo_id              0
# title                   0
# congress_session        0
# chamber                 0
# committee               0
# committee_mapped        0
# held_date               0
# members              3028
# bill_numbers        17863
# witnesses           12135
# dtype: int64

# %% [markdown]
# Here we check the format of all dates in the "held_date" column of the dataframe. We make sure all dates are no earlier than 1997. The publisher used simple REGEX to detect dates. Therefore, some dates from other places of the document get included in the dates. We manually updated all the dates in the hearing details JSON files. But by no means we have corrected all cases.

# %%
def check_date_format(df, date_col):
  num_incorrect = 0

  def is_valid_date_format(date_str):
    try:
      date_obj = pd.to_datetime(date_str, format='%B %d, %Y')
      return date_obj.year >= 1997
    except ValueError:
      return False

  def has_multiple_dates(date_str):
    return '\n' in date_str

  for i in range(len(df)):
    govinfo_id = df.loc[i, 'govinfo_id']
    date_str = df.loc[i, date_col]
    if is_valid_date_format(date_str):
      continue

    if has_multiple_dates(date_str):
      dates = date_str.split('\n')
      if not all(is_valid_date_format(date) for date in dates):
        num_incorrect += 1
        print(f"Hearing {govinfo_id} has invalid date.")
    else:
      num_incorrect += 1

  return num_incorrect

num_incorrect_formats = check_date_format(df_mapped, 'held_date')

print(f"Number of rows with incorrect format: {num_incorrect_formats}")
# Out:
# Number of rows with incorrect format: 0

# %%
def show_rows_with_length_mismatch(df, column_name, string_length):
  """
  This function shows rows in a DataFrame where a specific column's value length doesn't match a given length.

  Args:
      df (pandas.DataFrame): The DataFrame containing the column.
      column_name (str): The name of the column to check.
  """
  # Filter rows where the column length doesn't match the desired length
  filtered_df = df[df[column_name].str.len() != string_length]

  # Print the filtered DataFrame (containing rows with mismatched length)
  if not filtered_df.empty:
    print("Rows where", column_name, f"length doesn't match {string_length}:")
    return filtered_df
  else:
    print("All rows in", column_name, f"have a length of {string_length}.")

non_matching_df = show_rows_with_length_mismatch(df_mapped.copy(), 'govinfo_id', 17)
non_matching_df
# Out:
# Rows where govinfo_id length doesn't match 17:
#                   govinfo_id  \
# 50      CHRG-109shrg49104184
# 51      CHRG-109shrg49104171
# 56      CHRG-109shrg39104136
# 58      CHRG-109shrg49104169
# 60      CHRG-109shrg49104179
# ...                      ...
# 32253  CHRG-110shrg40547-err
# 32261  CHRG-110shrg41912-err
# 32333  CHRG-110shrg47451-err
# 32368  CHRG-110shrg41958-err
# 32407  CHRG-110shrg45240-err
#
#                                                    title congress_session  \
# 50     Senate Hearing, 109th Congress - Departments o...              109
# 51     Senate Hearing, 109th Congress - Departments o...              109
# 56     Senate Hearing, 109th Congress - Department of...              109
# 58     Senate Hearing, 109th Congress - Department of...              109
# 60     Senate Hearing, 109th Congress - Military Cons...              109
# ...                                                  ...              ...
# 32253  S. Hrg. 110-328 - [ERRATA] Hearing on Pending ...              110
# 32261  S. Hrg. 110-378 - [ERRATA] Hearing on Pending ...              110
# 32333  S. Hrg. 110-753 - [ERRATA] the "Material Suppo...              110
# 32368  S. Hrg. 110-357 - [ERRATA] the Rise of Drug-Re...              110
# 32407  S. Hrg. 110-584 - ERRATA - RESTORING THE RULE ...              110
#
#       chamber                       committee                committee_mapped  \
# 50     Senate     Committee on Appropriations     Committee on Appropriations
# 51     Senate     Committee on Appropriations     Committee on Appropriations
# 56     Senate     Committee on Appropriations     Committee on Appropriations
# 58     Senate     Committee on Appropriations     Committee on Appropriations
# 60     Senate     Committee on Appropriations     Committee on Appropriations
# ...       ...                             ...                             ...
# 32253  Senate  Committee on Veterans' Affairs  Committee on Veterans' Affairs
# 32261  Senate  Committee on Veterans' Affairs  Committee on Veterans' Affairs
# 32333  Senate      Committee on the Judiciary      Committee on the Judiciary
# 32368  Senate      Committee on the Judiciary      Committee on the Judiciary
# 32407  Senate      Committee on the Judiciary      Committee on the Judiciary
#
#                 held_date                                            members  \
# 50      February 17, 2005                                                NaN
# 51          March 2, 2005                                                NaN
# 56          March 2, 2005                                                NaN
# 58          March 2, 2005                                                NaN
# 60          March 8, 2005                                                NaN
# ...                   ...                                                ...
# 32253    October 24, 2007  Daniel K. Akaka (HI); Sherrod Brown (OH); Larr...
# 32261   November 14, 2007  Daniel K. Akaka (HI); Sherrod Brown (OH); Larr...
# 32333  September 19, 2007  Joseph R. Biden Jr. (DE); Sam Brownback (KS); ...
# 32368      March 24, 2008  Joseph R. Biden Jr. (DE); Sam Brownback (KS); ...
# 32407  September 16, 2008  Joseph R. Biden Jr. (DE); Sam Brownback (KS); ...
#
#                                             bill_numbers witnesses
# 50                                                   NaN       NaN
# 51                                                H.R. 1       NaN
# 56                                                   NaN       NaN
# 58                                      S. 352\nH.R. 418       NaN
# 60                                                   NaN       NaN
# ...                                                  ...       ...
# 32253  S. 38\nS. 2004\nS. 2142\nS. 2160\nS. 2162\nH.R...       NaN
# 32261                                   S. 2160\nS. 2162       NaN
# 32333                                                NaN       NaN
# 32368                                             S. 456       NaN
# 32407                                   S. 3401\nS. 3405       NaN
#
# [1086 rows x 10 columns]

# %%
df_err = df_mapped[df_mapped['govinfo_id'].str.endswith('-err')]
print(f"There are {len(df_err)} errata hearing records.")
# Out:
# There are 24 errata hearing records.

# %% [markdown]
# ### Export df in Parquet format

# %%
def store_df_to_parquet(df, filename):
  try:
    df.to_parquet(filename)
    print(f"DataFrame successfully stored to Parquet file: {filename}")
  except Exception as e:
    print(f"Error storing DataFrame to Parquet: {e}")

parquet_filename = "../datasets/hearing_details.parquet"

store_df_to_parquet(df_mapped, parquet_filename)
# Out:
# DataFrame successfully stored to Parquet file: ../datasets/hearing_details.parquet
